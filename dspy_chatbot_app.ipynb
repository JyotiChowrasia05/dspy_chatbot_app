# %% [markdown]
# <a href="https://colab.research.google.com/github/JyotiChowrasia05/dspy_chatbot_app/blob/main/dspy_chatbot_app.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install dspy-ai==0.0.19
# !pip install openai
# Out:
# ERROR: Ignored the following yanked versions: 2.4.3, 2.4.4, 2.4.6, 2.4.7
# ERROR: Could not find a version that satisfies the requirement dspy-ai==0.0.19 (from versions: 0.1.9, 2.0.0b1, 2.0.0b2, 2.0.1, 2.0.3, 2.0.4, 2.0.7, 2.0.8, 2.1.0, 2.1.1, 2.1.4, 2.1.5, 2.1.6, 2.1.7, 2.1.9, 2.1.10, 2.2.0, 2.3.0, 2.3.1, 2.3.2, 2.3.3, 2.3.4, 2.3.5, 2.3.6, 2.3.7, 2.4.0, 2.4.1, 2.4.5, 2.4.9, 2.4.10, 2.4.11, 2.4.12, 2.4.13, 2.4.14, 2.4.15, 2.4.16, 2.4.17, 2.5.0rc1, 2.5.0rc2, 2.5.0rc3, 2.5.0, 2.5.1, 2.5.2, 2.5.3, 2.5.4, 2.5.5, 2.5.6, 2.5.7, 2.5.8, 2.5.9, 2.5.10, 2.5.11, 2.5.12, 2.5.13, 2.5.14, 2.5.15, 2.5.16, 2.5.17, 2.5.18, 2.5.19, 2.5.20, 2.5.26, 2.5.27, 2.5.28, 2.5.29, 2.5.30, 2.5.31, 2.5.32, 2.5.33, 2.5.34, 2.5.35, 2.5.36, 2.5.37, 2.5.38, 2.5.39, 2.5.40, 2.5.41, 2.5.42)
# ERROR: No matching distribution found for dspy-ai==0.0.19
# ...

# %%
# signature include the task, input and output generated by LLM
import dspy
class ShakespeareanTransalation(dspy.Signature):
  """ Translate simple english to Shakespearsean English"""
  simple_english = dspy.InputField()
  shakkespearean_english = dspy.OutputField()

# %%
from google.colab import userdata
OPEN_AI_KEY = userdata.get('gemini_api_key')
turbo = dspy.OpenAI(model = 'gpt-3.5-turbo', max_tokens = 1000, api_key= OPEN_AI_KEY)

# %%
dspy.settings.configure(lm = turbo)
from dspy.signatures.signature import signature_to_template
shakespeare_transalation_as_template = signature_to_template(ShakespeareanTransalation)

# %%
print(str(shakespeare_transalation_as_template))
# Out:
# Template(Translate simple english to Shakespearsean English, ['Simple English:', 'Shakkespearean English:'])

# %%
class CoT(dspy.Module):
  def __init__(self):
    super().__init__()
    self.prog = dspy.ChainOfThought(ShakespeareanTransalation)

  def forward(self, simple_english):
    return self.prog(simple_english = simple_english)

result_english = CoT()

# %%
result_english.forward("You should relax and have fun while it lasts")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-28-a49d55561ca8> in <cell line: 1>()
# ----> 1 result_english.forward("You should relax and have fun while it lasts")
#
# <ipython-input-27-a1bd858f6dc7> in forward(self, simple_english)
#       5
#       6   def forward(self, simple_english):
# ----> 7     return self.prog(simple_english = simple_english)
#       8
#       9 result_english = CoT()
#
# /usr/local/lib/python3.10/dist-packages/dspy/utils/callback.py in wrapper(instance, *args, **kwargs)
#     232         # If no callbacks are provided, just call the function
#     233         if not callbacks:
# --> 234             return fn(instance, *args, **kwargs)
#     235
#     236         # Generate call ID as the unique identifier for the call, this is useful for instrumentation.
#
# ...

# %%
""" output - zero shot
prediction(
  rationale = 'produce the Shakespear English. We want to convey the message of enjoying the present
               moment without worrying about the future.'
  shakespear_english = 'Thou shoudst take ease and reveal whilst it doth endure'
)

"""
